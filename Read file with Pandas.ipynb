# %%
import pandas as pd

# %%
json_file = pd.read_json("2019-07-09-feedback.json", lines = True)

# %%
json_file
# Out:
#    AllowAccess                AttachedFileName  \
# 0         None                            None
# 1           on
# 2           on
# 3           on
# 4           on
# 5           on
# 6               Uploads/20190609112000364.jpeg
# 7           on
# 8                Uploads/2019060911314200.jpeg
# 9           on  Uploads/20190609113652642.jpeg
# 10          on  Uploads/20190609120640327.jpeg
# 11          on
# 12          on
# 13          on
# 14          on
#
#                                Comments                    Date  \
# 0                                  None 2019-07-09 11:09:39.671
# 1                                       2019-07-09 11:12:32.937
# 2                                       2019-07-09 11:13:15.823
# 3                                       2019-07-09 11:15:20.825
# 4                                       2019-07-09 11:15:49.833
# 5                                       2019-07-09 11:20:53.695
# 6                                       2019-07-09 11:20:55.054
# ...

# %%
log_json_file = pd.read_json("API_LOG_ALL.json", lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-be525c0245c7> in <module>
# ----> 1 log_json_file = pd.read_json("API_LOG_ALL.json", lines=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     532             data = to_str(self.data)
#     533             obj = self._get_object_parser(
# --> 534                 self._combine_lines(data.split('\n'))
#     535             )
#     536         else:
#
# ...

# %%
api_json = pd.read_csv("2019-06-26-api.log")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-0b9726ec5ff6> in <module>
# ----> 1 api_json = pd.read_csv("2019-06-26-api.log")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
# ...
